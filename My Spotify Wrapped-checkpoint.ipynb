# %%
import requests
import spotipy
from spotipy.oauth2 import SpotifyOAuth
import pandas as pd
import time
import datetime
import gspread

# %%
SPOTIPY_CLIENT_ID='561b97db161a4be6a9a56a22ead700db'
SPOTIPY_CLIENT_SECRET='2f72d3e46636425abeec96bee011c1ac'
SPOTIPY_REDIRECT_URI='http://127.0.0.1:9090'
SCOPE = "user-top-read"

# %%
sp = spotipy.Spotify(auth_manager=SpotifyOAuth(client_id=SPOTIPY_CLIENT_ID, 
                                               client_secret=SPOTIPY_CLIENT_SECRET, 
                                               redirect_uri=SPOTIPY_REDIRECT_URI, 
                                               scope=SCOPE))

# %%
top_tracks_short = sp.current_user_top_tracks(limit=10, offset=0, time_range="short_term")

# %%
top_tracks_short
# Out:
# {'items': [{'album': {'album_type': 'ALBUM',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6Ff53KvcvAj5U7Z1vojB5o'},
#       'href': 'https://api.spotify.com/v1/artists/6Ff53KvcvAj5U7Z1vojB5o',
#       'id': '6Ff53KvcvAj5U7Z1vojB5o',
#       'name': '*NSYNC',
#       'type': 'artist',
#       'uri': 'spotify:artist:6Ff53KvcvAj5U7Z1vojB5o'}],
#     'available_markets': ['AR',
#      'AU',
#      'AT',
#      'BE',
#      'BO',
#      'BR',
#      'BG',
#      'CA',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DK',
#      'DO',
#      'DE',
#      'EC',
#      'EE',
#      'SV',
#      'FI',
#      'FR',
#      'GR',
#      'GT',
#      'HN',
#      'HK',
#      'HU',
#      'IS',
#      'IE',
#      'IT',
#      'LV',
#      'LT',
#      'LU',
#      'MY',
#      'MT',
#      'MX',
#      'NL',
#      'NZ',
#      'NI',
#      'NO',
#      'PA',
#      'PY',
#      'PE',
#      'PH',
#      'PL',
#      'PT',
#      'SG',
# ...

# %%
top_tracks_short = sp.current_user_top_tracks(limit=20, offset=0, time_range="short_term")

# %%
type(top_tracks_short)
# Out:
# dict

# %%
def get_track_ids(time_frame):
    track_ids = []
    for song in time_frame['items']:
        track_ids.append(song['id'])
    return track_ids

# %%
track_ids = get_track_ids(top_tracks_short)

# %%
track_ids
# Out:
# ['62bOmKYxYg7dhrC6gH9vFn',
#  '5NgWHYbIUvWvoubsDVdPDa',
#  '1bjeWoagtHmUKputLVyDxQ',
#  '02Vl28l040OEC1kHTgGAkx',
#  '1UGD3lW3tDmgZfAVDh6w7r',
#  '1WxzZoWBTmB68AtyA6ejBB',
#  '3DarAbFujv6eYNliUTyqtz',
#  '3zYNRKf58j5tg5cg2YN2QN',
#  '4T7LQ7hVUL9sO59vmOtEnN',
#  '4w2GLmK2wnioVnb5CPQeex',
#  '5c9tBmJKbTdn1vhzXHeAwW',
#  '5npFBWhVs3VVlc0nY5xQMA',
#  '0JvGYvkdzouYaG96I20r0p',
#  '0PFZCt7UNmpas24HejQGu8',
#  '1Qrg8KqiBpW07V7PNxwwwL',
#  '3fhccxk3nJ49MjAuaS3iey',
#  '62fqMvguJbsSs9HKhhRfuS',
#  '0eIVnpxDX8TfzHAoObxLk1',
#  '27QxL30kLR6RyIjLXCMFdU',
#  '3Y1EvIgEVw51XtgNEgpz5c']

# %%
track_id = '62bOmKYxYg7dhrC6gH9vFn'

# %%
def get_track_features(id):
    meta = sp.track(id)
    # meta
    name = meta['name']
    album = meta['album']['name']
    artist = meta['album']['artists'][0]['name']
    spotify_url = meta['external_urls']['spotify']
    album_cover = meta['album']['images'][0]['url']
    track_info = [name, album, artist, spotify_url, album_cover]
    return track_info

# %%
get_track_features(track_id)
# Out:
# ['Bye Bye Bye - From Deadpool and Wolverine Soundtrack',
#  'No Strings Attached',
#  '*NSYNC',
#  'https://open.spotify.com/track/62bOmKYxYg7dhrC6gH9vFn',
#  'https://i.scdn.co/image/ab67616d0000b273a6cb8fab778e1efc406a5909']

# %%
tracks = []
for i in range(len(track_ids)):
    time.sleep(.5)
    track = get_track_features(track_ids[i])
    tracks.append(track)

# %%
tracks
# Out:
# [['Bye Bye Bye - From Deadpool and Wolverine Soundtrack',
#   'No Strings Attached',
#   '*NSYNC',
#   'https://open.spotify.com/track/62bOmKYxYg7dhrC6gH9vFn',
#   'https://i.scdn.co/image/ab67616d0000b273a6cb8fab778e1efc406a5909'],
#  ['Fratres for Strings and Percussion',
#   'The Place Beyond the Pines (Original Motion Picture Soundtrack)',
#   'Mike Patton',
#   'https://open.spotify.com/track/5NgWHYbIUvWvoubsDVdPDa',
#   'https://i.scdn.co/image/ab67616d0000b273d7f4dc0cb6a64852001625bb'],
#  ['Saturn',
#   'Saturn',
#   'SZA',
#   'https://open.spotify.com/track/1bjeWoagtHmUKputLVyDxQ',
#   'https://i.scdn.co/image/ab67616d0000b273d70916ee9e40c90380ba5f07'],
#  ['Aah Ko Chahiye - 1988',
#   'Mirza Ghalib - T V Serial',
#   'Jagjit Singh',
#   'https://open.spotify.com/track/02Vl28l040OEC1kHTgGAkx',
#   'https://i.scdn.co/image/ab67616d0000b273a41a5ab4a30ee7f020bed53b'],
#  ['Devil In A New Dress',
#   'My Beautiful Dark Twisted Fantasy',
#   'Kanye West',
# ...

# %%
df = pd.DataFrame(tracks, columns = ['name', 'album', 'artist', 'spotify_url', 'album_cover'])
df.head(5)
# Out:
#                                                 name  \
# 0  Bye Bye Bye - From Deadpool and Wolverine Soun...
# 1                 Fratres for Strings and Percussion
# 2                                             Saturn
# 3                              Aah Ko Chahiye - 1988
# 4                               Devil In A New Dress
#
#                                                album        artist  \
# 0                                No Strings Attached        *NSYNC
# 1  The Place Beyond the Pines (Original Motion Pi...   Mike Patton
# 2                                             Saturn           SZA
# 3                          Mirza Ghalib - T V Serial  Jagjit Singh
# 4                  My Beautiful Dark Twisted Fantasy    Kanye West
#
#                                          spotify_url  \
# 0  https://open.spotify.com/track/62bOmKYxYg7dhrC...
# 1  https://open.spotify.com/track/5NgWHYbIUvWvoub...
# 2  https://open.spotify.com/track/1bjeWoagtHmUKpu...
# ...

# %%
import gspread

# %%
gc = gspread.service_account(filename=r"C:\Users\admin\Desktop\inner-autonomy-434719-d5-837827a6babe.json")

# %%
sh = gc.open("My Spotify Wrapped")

# %%
worksheet = sh.worksheet("short_term")

# %%
val = worksheet.acell('B5').value
val
# Out:
# 'FIND ME!!'

# %%
# worksheet.update([dataframe.columns.values.tolist()] + dataframe.values.tolist())

# %%
# insert into sheet
def insert_to_gsheet(track_ids):
    # loop over track ids 
    tracks = []
    for i in range(len(track_ids)):
        time.sleep(.5)
        track = get_track_features(track_ids[i])
        tracks.append(track)
    # create dataframe
    df = pd.DataFrame(tracks, columns = ['name', 'album', 'artist', 'spotify_url', 'album_cover'])
    # insert into google sheet
    gc = gspread.service_account(filename=r"C:\Users\admin\Desktop\inner-autonomy-434719-d5-837827a6babe.json")
    sh = gc.open('My Spotify Wrapped')
    worksheet = sh.worksheet(f'{time_period}')
    worksheet.update([df.columns.values.tolist()] + df.values.tolist())
    print('Done')

# %%
time_ranges = ['short_term', 'medium_term', 'long_term']
for time_period in time_ranges:
    top_tracks = sp.current_user_top_tracks(limit=20, offset=0, time_range=time_period)
    track_ids = get_track_ids(top_tracks)
    insert_to_gsheet(track_ids)
# Out:
# Done
# Done
# Done
